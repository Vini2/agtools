# %%
! agtools --help
# Out:
# Usage: agtools [OPTIONS] COMMAND [ARGS]...
#
#   agtools: A Software Framework to Manipulate Assembly Graphs
#
# Options:
#   -v, --version  Show the version and exit.
#   -h, --help     Show this message and exit.
#
# Commands:
#   stats      Compute statistics about the graph
#   rename     Rename segments, paths and walks in a GFA file
#   concat     Concatenate two or more GFA files
#   filter     Filter segments from GFA file
#   clean      Clean a GFA file based on segments in a FASTA file
#   component  Extract a component containing a given segment
#   fastg2gfa  Convert FASTG file to GFA format
#   asqg2gfa   Convert ASQG file to GFA format
#   gfa2dot    Convert GFA file to DOT format (GraphViz)
#   gfa2fasta  Get segments in FASTA format
#   gfa2adj    Get adjacency matrix of the assembly graph

# %% [markdown]
# # Basic commands

# %% [markdown]
# ## `stats`

# %%
! agtools stats --help
# Out:
# Usage: agtools stats [OPTIONS]
#
#   Compute statistics about the graph
#
# Options:
#   -g, --graph PATH   path(s) to the assembly graph file(s)  [required]
#   -o, --output PATH  path to the output folder  [required]
#   -h, --help         Show this message and exit.

# %%
! agtools stats -g ../tests/data/ESC/assembly_graph_with_scaffolds.gfa -o ./
# Out:
# 2025-09-16 14:36:56.547 | INFO     | agtools.cli:begin_agtools:323 - agtools: A Software Framework to Manipulate Assembly Graphs
# 2025-09-16 14:36:56.547 | INFO     | agtools.cli:begin_agtools:324 - You are using agtools version 1.0.2
# 2025-09-16 14:36:56.547 | INFO     | agtools.cli:begin_agtools:326 - Repository homepage is https://github.com/Vini2/agtools
# 2025-09-16 14:36:56.547 | INFO     | agtools.cli:begin_agtools:327 - You are running agtools stats
# 2025-09-16 14:36:56.547 | INFO     | agtools.cli:begin_agtools:328 - Listing parameters
# 2025-09-16 14:36:56.547 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --graph ('../tests/data/ESC/assembly_graph_with_scaffolds.gfa',)
# 2025-09-16 14:36:56.547 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --output ./
# 2025-09-16 14:36:56.547 | INFO     | agtools.cli:stats:82 - Computing statistics of the graph file ../tests/data/ESC/assembly_graph_with_scaffolds.gfa
# 2025-09-16 14:36:56.602 | INFO     | agtools.commands.stats:stats:112 - Basic graph statistics for ../tests/data/ESC/assembly_graph_with_scaffolds.gfa:
# 2025-09-16 14:36:56.602 | INFO     | agtools.commands.stats:stats:113 - Number of segments: 982
# 2025-09-16 14:36:56.602 | INFO     | agtools.commands.stats:stats:114 - Number of links: 1265
# 2025-09-16 14:36:56.602 | INFO     | agtools.commands.stats:stats:115 - Number of self-loops: 1
# 2025-09-16 14:36:56.602 | INFO     | agtools.commands.stats:stats:116 - Number of connected components: 4
# 2025-09-16 14:36:56.602 | INFO     | agtools.commands.stats:stats:117 - Average node degree: 2.576374745417515
# 2025-09-16 14:36:56.602 | INFO     | agtools.commands.stats:stats:118 - Sequence-based statistics for ../tests/data/ESC/assembly_graph_with_scaffolds.gfa:
# 2025-09-16 14:36:56.602 | INFO     | agtools.commands.stats:stats:119 - Total length of segments: 8337494 bp
# 2025-09-16 14:36:56.602 | INFO     | agtools.commands.stats:stats:120 - Average segment length: 8490.319755600814 bp
# 2025-09-16 14:36:56.602 | INFO     | agtools.commands.stats:stats:121 - N50: 60706 bp
# 2025-09-16 14:36:56.602 | INFO     | agtools.commands.stats:stats:122 - L50: 36 segment(s)
# 2025-09-16 14:36:56.602 | INFO     | agtools.commands.stats:stats:123 - GC content: 43.52%
# 2025-09-16 14:36:56.602 | INFO     | agtools.cli:stats:86 - Computed statistics can be found in .//graph_stats.txt

# %% [markdown]
# ## `rename`

# %%
! agtools rename --help
# Out:
# Usage: agtools rename [OPTIONS]
#
#   Rename segments, paths and walks in a GFA file
#
# Options:
#   -g, --graph PATH   path(s) to the assembly graph file(s)  [required]
#   -p, --prefix TEXT  prefix for the graph elements  [default: ""]
#   -o, --output PATH  path to the output folder  [required]
#   -h, --help         Show this message and exit.

# %%
! agtools rename -g ../tests/data/test_graph.gfa -p test -o ./
# Out:
# 2025-09-16 14:36:57.846 | INFO     | agtools.cli:begin_agtools:323 - agtools: A Software Framework to Manipulate Assembly Graphs
# 2025-09-16 14:36:57.846 | INFO     | agtools.cli:begin_agtools:324 - You are using agtools version 1.0.2
# 2025-09-16 14:36:57.846 | INFO     | agtools.cli:begin_agtools:326 - Repository homepage is https://github.com/Vini2/agtools
# 2025-09-16 14:36:57.846 | INFO     | agtools.cli:begin_agtools:327 - You are running agtools rename
# 2025-09-16 14:36:57.846 | INFO     | agtools.cli:begin_agtools:328 - Listing parameters
# 2025-09-16 14:36:57.846 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --graph ('../tests/data/test_graph.gfa',)
# 2025-09-16 14:36:57.846 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --prefix test
# 2025-09-16 14:36:57.846 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --output ./
# 2025-09-16 14:36:57.846 | INFO     | agtools.cli:rename:106 - Renaming elements in graph file ../tests/data/test_graph.gfa
# 2025-09-16 14:36:57.846 | INFO     | agtools.cli:rename:107 - Prefix used is test
# 2025-09-16 14:36:57.847 | INFO     | agtools.cli:rename:111 - Renamed graph file is .//renamed_graph.gfa

# %% [markdown]
# ## `concat`

# %%
! agtools concat --help
# Out:
# Usage: agtools concat [OPTIONS]
#
#   Concatenate two or more GFA files
#
# Options:
#   -g, --graph PATH   path(s) to the assembly graph file(s)  [required]
#   -o, --output PATH  path to the output folder  [required]
#   -h, --help         Show this message and exit.

# %%
! agtools concat -g ../tests/data/test_graph.gfa -g ../tests/data/test_graph_1.gfa -o ./
# Out:
# 2025-09-16 14:36:59.112 | INFO     | agtools.cli:begin_agtools:323 - agtools: A Software Framework to Manipulate Assembly Graphs
# 2025-09-16 14:36:59.113 | INFO     | agtools.cli:begin_agtools:324 - You are using agtools version 1.0.2
# 2025-09-16 14:36:59.113 | INFO     | agtools.cli:begin_agtools:326 - Repository homepage is https://github.com/Vini2/agtools
# 2025-09-16 14:36:59.113 | INFO     | agtools.cli:begin_agtools:327 - You are running agtools concat
# 2025-09-16 14:36:59.113 | INFO     | agtools.cli:begin_agtools:328 - Listing parameters
# 2025-09-16 14:36:59.113 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --graph ('../tests/data/test_graph.gfa', '../tests/data/test_graph_1.gfa')
# 2025-09-16 14:36:59.113 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --output ./
# 2025-09-16 14:36:59.113 | INFO     | agtools.cli:concat:123 - Concatenating graph files [../tests/data/test_graph.gfa, ../tests/data/test_graph_1.gfa]
# 2025-09-16 14:36:59.114 | INFO     | agtools.cli:concat:127 - Concatenated graph file is .//concatenated_graph.gfa

# %% [markdown]
# ## `filter`

# %%
! agtools filter --help
# Out:
# Usage: agtools filter [OPTIONS]
#
#   Filter segments from GFA file
#
# Options:
#   -g, --graph PATH          path(s) to the assembly graph file(s)  [required]
#   -l, --min-length INTEGER  minimum length of segments to keep  [default: 100;
#                             required]
#   -o, --output PATH         path to the output folder  [required]
#   -h, --help                Show this message and exit.

# %%
! agtools filter -g ../tests/data/test_graph.gfa -l 20 -o ./
# Out:
# 2025-09-16 14:37:00.379 | INFO     | agtools.cli:begin_agtools:323 - agtools: A Software Framework to Manipulate Assembly Graphs
# 2025-09-16 14:37:00.379 | INFO     | agtools.cli:begin_agtools:324 - You are using agtools version 1.0.2
# 2025-09-16 14:37:00.379 | INFO     | agtools.cli:begin_agtools:326 - Repository homepage is https://github.com/Vini2/agtools
# 2025-09-16 14:37:00.379 | INFO     | agtools.cli:begin_agtools:327 - You are running agtools filter
# 2025-09-16 14:37:00.379 | INFO     | agtools.cli:begin_agtools:328 - Listing parameters
# 2025-09-16 14:37:00.379 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --graph ('../tests/data/test_graph.gfa',)
# 2025-09-16 14:37:00.379 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --min-length 20
# 2025-09-16 14:37:00.379 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --output ./
# 2025-09-16 14:37:00.379 | INFO     | agtools.cli:filter:148 - Filtering segments in graph file ../tests/data/test_graph.gfa
# 2025-09-16 14:37:00.379 | INFO     | agtools.cli:filter:149 - Minimum length of segments to keep is 20 bp
# 2025-09-16 14:37:00.379 | INFO     | agtools.commands.filter:filter:120 - Identified 1 segments shorter than 20 bp to remove
# 2025-09-16 14:37:00.379 | INFO     | agtools.cli:filter:153 - Filtered graph file is .//filtered_graph.gfa

# %% [markdown]
# ## `component`

# %%
! agtools component --help
# Out:
# Usage: agtools component [OPTIONS]
#
#   Extract a component containing a given segment
#
# Options:
#   -g, --graph PATH    path(s) to the assembly graph file(s)  [required]
#   -s, --segment TEXT  segment ID  [required]
#   -o, --output PATH   path to the output folder  [required]
#   -h, --help          Show this message and exit.

# %%
! agtools component -g ../tests/data/test_graph.gfa -s seg4 -o ./
# Out:
# 2025-09-16 14:37:01.697 | INFO     | agtools.cli:begin_agtools:323 - agtools: A Software Framework to Manipulate Assembly Graphs
# 2025-09-16 14:37:01.697 | INFO     | agtools.cli:begin_agtools:324 - You are using agtools version 1.0.2
# 2025-09-16 14:37:01.697 | INFO     | agtools.cli:begin_agtools:326 - Repository homepage is https://github.com/Vini2/agtools
# 2025-09-16 14:37:01.697 | INFO     | agtools.cli:begin_agtools:327 - You are running agtools component
# 2025-09-16 14:37:01.697 | INFO     | agtools.cli:begin_agtools:328 - Listing parameters
# 2025-09-16 14:37:01.697 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --graph ('../tests/data/test_graph.gfa',)
# 2025-09-16 14:37:01.697 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --segment seg4
# 2025-09-16 14:37:01.697 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --output ./
# 2025-09-16 14:37:01.697 | INFO     | agtools.cli:component:205 - Extracting from file ../tests/data/test_graph.gfa the component containing segment seg4
# 2025-09-16 14:37:01.698 | INFO     | agtools.cli:component:211 - GFA file of the component is written to .//component_graph.gfa

# %% [markdown]
# # Format conversion commands

# %% [markdown]
# ## `fastg2gfa`

# %%
! agtools fastg2gfa --help
# Out:
# Usage: agtools fastg2gfa [OPTIONS]
#
#   Convert FASTG file to GFA format
#
# Options:
#   -g, --graph PATH     path(s) to the assembly graph file(s)  [required]
#   -k, --ksize INTEGER  k-mer size used for the assembly  [default: 141;
#                        required]
#   -o, --output PATH    path to the output folder  [required]
#   -h, --help           Show this message and exit.

# %%
! agtools fastg2gfa -g ../tests/data/final.graph.fastg -o ./
# Out:
# 2025-09-16 14:37:02.945 | INFO     | agtools.cli:begin_agtools:323 - agtools: A Software Framework to Manipulate Assembly Graphs
# 2025-09-16 14:37:02.945 | INFO     | agtools.cli:begin_agtools:324 - You are using agtools version 1.0.2
# 2025-09-16 14:37:02.945 | INFO     | agtools.cli:begin_agtools:326 - Repository homepage is https://github.com/Vini2/agtools
# 2025-09-16 14:37:02.945 | INFO     | agtools.cli:begin_agtools:327 - You are running agtools fastg2gfa
# 2025-09-16 14:37:02.945 | INFO     | agtools.cli:begin_agtools:328 - Listing parameters
# 2025-09-16 14:37:02.945 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --graph ('../tests/data/final.graph.fastg',)
# 2025-09-16 14:37:02.945 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --output ./
# 2025-09-16 14:37:02.945 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --ksize 141
# 2025-09-16 14:37:02.945 | INFO     | agtools.cli:fastg2gfa:232 - Converting FASTG file ../tests/data/final.graph.fastg to GFA format
# 2025-09-16 14:37:02.945 | INFO     | agtools.cli:fastg2gfa:233 - k-mer size 141 will be used as the overlap
# 2025-09-16 14:37:02.949 | INFO     | agtools.cli:fastg2gfa:237 - GFA file is written to .//converted_graph.gfa with fixed overlap: 141M

# %% [markdown]
# ## `asqg2gfa`

# %%
! agtools asqg2gfa --help
# Out:
# Usage: agtools asqg2gfa [OPTIONS]
#
#   Convert ASQG file to GFA format
#
# Options:
#   -g, --graph PATH   path(s) to the assembly graph file(s)  [required]
#   -o, --output PATH  path to the output folder  [required]
#   -h, --help         Show this message and exit.

# %%
! agtools asqg2gfa -g ../tests/data/ESC/default-graph.asqg -o ./
# Out:
# 2025-09-16 14:37:04.179 | INFO     | agtools.cli:begin_agtools:323 - agtools: A Software Framework to Manipulate Assembly Graphs
# 2025-09-16 14:37:04.180 | INFO     | agtools.cli:begin_agtools:324 - You are using agtools version 1.0.2
# 2025-09-16 14:37:04.180 | INFO     | agtools.cli:begin_agtools:326 - Repository homepage is https://github.com/Vini2/agtools
# 2025-09-16 14:37:04.180 | INFO     | agtools.cli:begin_agtools:327 - You are running agtools asqg2gfa
# 2025-09-16 14:37:04.180 | INFO     | agtools.cli:begin_agtools:328 - Listing parameters
# 2025-09-16 14:37:04.180 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --graph ('../tests/data/ESC/default-graph.asqg',)
# 2025-09-16 14:37:04.180 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --output ./
# 2025-09-16 14:37:04.180 | INFO     | agtools.cli:asqg2gfa:249 - Converting ASQG file ../tests/data/ESC/default-graph.asqg to GFA format
# 2025-09-16 14:37:04.201 | INFO     | agtools.cli:asqg2gfa:253 - GFA file is written to .//converted_graph.gfa

# %% [markdown]
# ## `gfa2dot`

# %%
! agtools gfa2dot --help
# Out:
# Usage: agtools gfa2dot [OPTIONS]
#
#   Convert GFA file to DOT format (GraphViz)
#
# Options:
#   -g, --graph PATH   path(s) to the assembly graph file(s)  [required]
#   -ab, --abyss       use the ABySS DOT format for the output
#   -o, --output PATH  path to the output folder  [required]
#   -h, --help         Show this message and exit.

# %% [markdown]
# GraphViz GOT format

# %%
! agtools gfa2dot -g ../tests/data/test_graph.gfa -o ./
# Out:
# 2025-09-16 14:37:05.450 | INFO     | agtools.cli:begin_agtools:323 - agtools: A Software Framework to Manipulate Assembly Graphs
# 2025-09-16 14:37:05.450 | INFO     | agtools.cli:begin_agtools:324 - You are using agtools version 1.0.2
# 2025-09-16 14:37:05.450 | INFO     | agtools.cli:begin_agtools:326 - Repository homepage is https://github.com/Vini2/agtools
# 2025-09-16 14:37:05.450 | INFO     | agtools.cli:begin_agtools:327 - You are running agtools gfa2dot
# 2025-09-16 14:37:05.450 | INFO     | agtools.cli:begin_agtools:328 - Listing parameters
# 2025-09-16 14:37:05.450 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --graph ('../tests/data/test_graph.gfa',)
# 2025-09-16 14:37:05.451 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --output ./
# 2025-09-16 14:37:05.451 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --abyss False
# 2025-09-16 14:37:05.451 | INFO     | agtools.cli:gfa2dot:274 - Converting GFA file ../tests/data/test_graph.gfa to DOT format
# 2025-09-16 14:37:05.452 | INFO     | agtools.cli:gfa2dot:278 - DOT file written to .//graph.dot

# %% [markdown]
# ABySS DOT format

# %%
! agtools gfa2dot -g ../tests/data/test_graph.gfa -ab -o ./
# Out:
# 2025-09-16 14:37:06.073 | INFO     | agtools.cli:begin_agtools:323 - agtools: A Software Framework to Manipulate Assembly Graphs
# 2025-09-16 14:37:06.073 | INFO     | agtools.cli:begin_agtools:324 - You are using agtools version 1.0.2
# 2025-09-16 14:37:06.073 | INFO     | agtools.cli:begin_agtools:326 - Repository homepage is https://github.com/Vini2/agtools
# 2025-09-16 14:37:06.074 | INFO     | agtools.cli:begin_agtools:327 - You are running agtools gfa2dot
# 2025-09-16 14:37:06.074 | INFO     | agtools.cli:begin_agtools:328 - Listing parameters
# 2025-09-16 14:37:06.074 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --graph ('../tests/data/test_graph.gfa',)
# 2025-09-16 14:37:06.074 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --abyss True
# 2025-09-16 14:37:06.074 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --output ./
# 2025-09-16 14:37:06.074 | INFO     | agtools.cli:gfa2dot:274 - Converting GFA file ../tests/data/test_graph.gfa to DOT format
# 2025-09-16 14:37:06.074 | INFO     | agtools.cli:gfa2dot:278 - DOT file written to .//graph.gv

# %% [markdown]
# ## `gfa2fasta`

# %%
! agtools gfa2fasta --help
# Out:
# Usage: agtools gfa2fasta [OPTIONS]
#
#   Get segments in FASTA format
#
# Options:
#   -g, --graph PATH   path(s) to the assembly graph file(s)  [required]
#   -o, --output PATH  path to the output folder  [required]
#   -h, --help         Show this message and exit.

# %%
! agtools gfa2fasta -g ../tests/data/test_graph.gfa -o ./
# Out:
# 2025-09-16 14:37:07.329 | INFO     | agtools.cli:begin_agtools:323 - agtools: A Software Framework to Manipulate Assembly Graphs
# 2025-09-16 14:37:07.329 | INFO     | agtools.cli:begin_agtools:324 - You are using agtools version 1.0.2
# 2025-09-16 14:37:07.329 | INFO     | agtools.cli:begin_agtools:326 - Repository homepage is https://github.com/Vini2/agtools
# 2025-09-16 14:37:07.329 | INFO     | agtools.cli:begin_agtools:327 - You are running agtools gfa2fasta
# 2025-09-16 14:37:07.329 | INFO     | agtools.cli:begin_agtools:328 - Listing parameters
# 2025-09-16 14:37:07.329 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --graph ('../tests/data/test_graph.gfa',)
# 2025-09-16 14:37:07.329 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --output ./
# 2025-09-16 14:37:07.329 | INFO     | agtools.cli:gfa2fasta:290 - Extracting segment sequences from ../tests/data/test_graph.gfa file in to FASTA format
# 2025-09-16 14:37:07.337 | INFO     | agtools.cli:gfa2fasta:294 - FASTA file written to .//segments.fasta

# %% [markdown]
# ## `gfa2adj`

# %%
! agtools gfa2adj --help
# Out:
# Usage: agtools gfa2adj [OPTIONS]
#
#   Get adjacency matrix of the assembly graph
#
# Options:
#   -g, --graph PATH         path(s) to the assembly graph file(s)  [required]
#   --delimiter [comma|tab]  delimiter for adjacency file. Supports a comma and
#                            a tab.  [default: comma]
#   -o, --output PATH        path to the output folder  [required]
#   -h, --help               Show this message and exit.

# %%
! agtools gfa2adj -g ../tests/data/test_graph.gfa -o ./
# Out:
# 2025-09-16 14:37:08.657 | INFO     | agtools.cli:begin_agtools:323 - agtools: A Software Framework to Manipulate Assembly Graphs
# 2025-09-16 14:37:08.657 | INFO     | agtools.cli:begin_agtools:324 - You are using agtools version 1.0.2
# 2025-09-16 14:37:08.657 | INFO     | agtools.cli:begin_agtools:326 - Repository homepage is https://github.com/Vini2/agtools
# 2025-09-16 14:37:08.657 | INFO     | agtools.cli:begin_agtools:327 - You are running agtools gfa2adj
# 2025-09-16 14:37:08.657 | INFO     | agtools.cli:begin_agtools:328 - Listing parameters
# 2025-09-16 14:37:08.657 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --graph ('../tests/data/test_graph.gfa',)
# 2025-09-16 14:37:08.657 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --output ./
# 2025-09-16 14:37:08.657 | INFO     | agtools.cli:begin_agtools:331 - Parameter: --delimiter comma
# 2025-09-16 14:37:08.658 | INFO     | agtools.cli:gfa2adj:314 - Obtaining the adjacency matrix from ../tests/data/test_graph.gfa
# 2025-09-16 14:37:08.662 | INFO     | agtools.cli:gfa2adj:318 - Adjacency matrix is written to .//adjacency_matrix.csv
